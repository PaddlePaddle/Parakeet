# %%
import librosa
from librosa import display
from parakeet.datasets import ljspeech
# %matplotlib inline

# %%
ljspeech_dataset = ljspeech.LJSpeech("/workspace/datasets/LJSpeech-1.1/")

# %%
example = ljspeech_dataset[0] # mag, mel, text

# %%
print(example)
# Out:
# (array([[ -0.27462918,  -6.2973747 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ],
#        [ -0.27177352,  -6.2941885 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ],
#        [ -0.26818287,  -6.2838745 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ],
#        ...,
#        [ -0.2587558 ,  -6.2825537 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ],
#        [ -0.25943533,  -6.2737536 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ],
#        [ -0.26199442,  -6.2909927 , -48.616695  , ..., -48.616695  ,
#         -48.616695  , -48.616695  ]], dtype=float32), array([[0.7972537 , 0.7370262 , 0.313833  , ..., 0.313833  , 0.313833  ,
#         0.313833  ],
#        [0.7972823 , 0.7370581 , 0.313833  , ..., 0.313833  , 0.313833  ,
#         0.313833  ],
#        [0.7973182 , 0.7371613 , 0.313833  , ..., 0.313833  , 0.313833  ,
#         0.313833  ],
#        ...,
# ...

# %%
display.specshow(example[0])

# %%
display.specshow(example[1])
